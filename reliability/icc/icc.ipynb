# %% [markdown]
# ---
# title: Informes Cambio de Componentes
# subtitle: Revisión de completitud
# author: Chief Reliability
# date: 2023-01-23
# ---

# %%
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload

import sys
from pathlib import Path


import pandas as pd
import polars as pl
import dagster as dg
from kdags.resources import *
from io import BytesIO
import pdfplumber
from datetime import datetime
import re
import os
from kdags.definitions import *
from kdags.readr import Readr
from kdags.resources.ggplot import *
from kdags.resources.tidyr import *

import matplotlib.pyplot as plt
import numpy as np

# from itables import init_notebook_mode, show
from datetime import date

# init_notebook_mode(all_interactive=True)

context = dg.build_asset_context()


def generate_weekly_summary(df):

    weekly_summary = df.group_by("changeout_week").agg(
        pl.col("changeout_date").count().alias("total"),
        (~pl.col("has_report")).cast(pl.Int64).sum().alias("missing"),
    )

    # Calculate percentages and available counts
    weekly_summary = weekly_summary.with_columns(
        (pl.col("missing") / pl.col("total") * 100)
        .round(1)
        .alias("missing_percentage"),
        (pl.col("total") - pl.col("missing")).alias("available"),
    )

    # Sort by week to ensure chronological order
    weekly_summary = weekly_summary.sort("changeout_week", descending=True)

    # Filter to weeks with at least one record
    weekly_summary = weekly_summary.filter(pl.col("total") > 0)

    return weekly_summary


def plot_icc_report(weekly_summary):
    """
    Create the ICC report visualization using GGPrism.

    Parameters:
        weekly_summary (pd.DataFrame): Weekly summary from generate_weekly_summary function

    Returns:
        tuple: (fig, ax) - Matplotlib figure and axis objects
    """
    # Create theme and figure
    theme = GGPrism()
    fig, ax = theme.create_figure(figsize=(12, 7))

    # Plot stacked bars
    x = np.arange(len(weekly_summary))
    ax.bar(
        x,
        weekly_summary["available"],
        width=0.85,
        color=theme.COLORS[0],
        label="Available",
        edgecolor="white",
        linewidth=0.8,
    )
    ax.bar(
        x,
        weekly_summary["missing"],
        width=0.85,
        bottom=weekly_summary["available"],
        color=theme.COLORS[4],
        label="Missing",
        edgecolor="white",
        linewidth=0.8,
    )

    # Add percentage labels with improved positioning
    for i, row in enumerate(weekly_summary.itertuples()):
        # Adjust vertical position based on total value to prevent overlap
        vertical_offset = 0.3  # Base offset

        # Add more space for higher bars to prevent label overlap
        if row.total >= 5:
            vertical_offset = 0.4

        if row.missing > 0:
            ax.text(
                i,
                row.total + vertical_offset,
                f"{int(row.missing_percentage)}%",
                ha="center",
                va="bottom",
                fontsize=13,
                fontweight="bold",
                color=theme.FIXED_COLORS["axis_color"],
            )
        else:
            ax.text(
                i,
                row.total + vertical_offset,
                "0%",
                ha="center",
                va="bottom",
                fontsize=13,
                fontweight="bold",
                color=theme.FIXED_COLORS["axis_color"],
            )

    # Set x-ticks
    ax.set_xticks(x)
    ax.set_xticklabels(weekly_summary["week"], rotation=90)

    # Ensure y-axis has enough room for labels
    y_max = max(weekly_summary["total"]) + 1.5  # Add extra space for labels
    ax.set_ylim(0, y_max)

    # Apply styling and finalize plot
    theme.style_legend(ax, title="Report Status", loc="upper right")
    theme.finalize_plot(
        fig,
        ax,
        title="Weekly ICC Reports Status",
        xlabel="Week",
        ylabel="Number of Reports",
    )

    return fig


result = kdefs.get_job_def("icc_job").execute_in_process(raise_on_error=True)

# %%
result = kdefs.get_job_def("icc_job").execute_in_process(raise_on_error=True)
# Out:
# 2025-04-10 09:03:01 -0400 - dagster - DEBUG - icc_job - c140f2ca-00cd-451a-a765-1127c3d521ff - 21648 - RUN_START - Started execution of run for "icc_job".
# 2025-04-10 09:03:01 -0400 - dagster - DEBUG - icc_job - c140f2ca-00cd-451a-a765-1127c3d521ff - 21648 - ENGINE_EVENT - Executing steps in process (pid: 21648)
# 2025-04-10 09:03:01 -0400 - dagster - DEBUG - icc_job - c140f2ca-00cd-451a-a765-1127c3d521ff - 21648 - RESOURCE_INIT_STARTED - Starting initialization of resources [io_manager].
# 2025-04-10 09:03:01 -0400 - dagster - DEBUG - icc_job - c140f2ca-00cd-451a-a765-1127c3d521ff - 21648 - RESOURCE_INIT_SUCCESS - Finished initialization of resources [io_manager].
# 2025-04-10 09:03:01 -0400 - dagster - DEBUG - icc_job - c140f2ca-00cd-451a-a765-1127c3d521ff - 21648 - LOGS_CAPTURED - Started capturing logs in process (pid: 21648).
# 2025-04-10 09:03:01 -0400 - dagster - DEBUG - icc_job - c140f2ca-00cd-451a-a765-1127c3d521ff - 21648 - gather_icc_reports - STEP_START - Started execution of step "gather_icc_reports".
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# 2025-04-10 09:03:42 -0400 - dagster - DEBUG - icc_job - c140f2ca-00cd-451a-a765-1127c3d521ff - 21648 - gather_icc_reports - STEP_OUTPUT - Yielded output "result" of type "Any". (Type check passed).
# 2025-04-10 09:03:42 -0400 - dagster - DEBUG - icc_job - c140f2ca-00cd-451a-a765-1127c3d521ff - gather_icc_reports - Writing file at: C:\Users\andmn\AppData\Local\Temp\tmpe_rjzm_9\storage\gather_icc_reports using PickledObjectFilesystemIOManager...
# 2025-04-10 09:03:42 -0400 - dagster - DEBUG - icc_job - c140f2ca-00cd-451a-a765-1127c3d521ff - 21648 - gather_icc_reports - ASSET_MATERIALIZATION - Materialized value gather_icc_reports.
# 2025-04-10 09:03:42 -0400 - dagster - DEBUG - icc_job - c140f2ca-00cd-451a-a765-1127c3d521ff - 21648 - gather_icc_reports - HANDLED_OUTPUT - Handled output "result" using IO manager "io_manager"
# 2025-04-10 09:03:42 -0400 - dagster - DEBUG - icc_job - c140f2ca-00cd-451a-a765-1127c3d521ff - 21648 - gather_icc_reports - STEP_SUCCESS - Finished execution of step "gather_icc_reports" in 41.72s.
# 2025-04-10 09:03:42 -0400 - dagster - DEBUG - icc_job - c140f2ca-00cd-451a-a765-1127c3d521ff - 21648 - read_component_changeouts - STEP_START - Started execution of step "read_component_changeouts".
# 2025-04-10 09:03:44 -0400 - dagster - INFO - icc_job - c140f2ca-00cd-451a-a765-1127c3d521ff - read_component_changeouts - Read 2969 records from abfs://bhp-analytics-data/PLANNING/COMPONENT_CHANGEOUTS/component_changeouts.parquet.
# 2025-04-10 09:03:44 -0400 - dagster - DEBUG - icc_job - c140f2ca-00cd-451a-a765-1127c3d521ff - 21648 - read_component_changeouts - STEP_OUTPUT - Yielded output "result" of type "DataFrame". (Type check passed).
# 2025-04-10 09:03:44 -0400 - dagster - DEBUG - icc_job - c140f2ca-00cd-451a-a765-1127c3d521ff - read_component_changeouts - Writing file at: C:\Users\andmn\AppData\Local\Temp\tmpe_rjzm_9\storage\read_component_changeouts using PickledObjectFilesystemIOManager...
# 2025-04-10 09:03:44 -0400 - dagster - DEBUG - icc_job - c140f2ca-00cd-451a-a765-1127c3d521ff - 21648 - read_component_changeouts - ASSET_MATERIALIZATION - Materialized value read_component_changeouts.
# 2025-04-10 09:03:44 -0400 - dagster - DEBUG - icc_job - c140f2ca-00cd-451a-a765-1127c3d521ff - 21648 - read_component_changeouts - HANDLED_OUTPUT - Handled output "result" using IO manager "io_manager"
# 2025-04-10 09:03:44 -0400 - dagster - DEBUG - icc_job - c140f2ca-00cd-451a-a765-1127c3d521ff - 21648 - read_component_changeouts - STEP_SUCCESS - Finished execution of step "read_component_changeouts" in 1.71s.
# 2025-04-10 09:03:44 -0400 - dagster - DEBUG - icc_job - c140f2ca-00cd-451a-a765-1127c3d521ff - 21648 - cc_summary - STEP_START - Started execution of step "cc_summary".
# 2025-04-10 09:03:44 -0400 - dagster - DEBUG - icc_job - c140f2ca-00cd-451a-a765-1127c3d521ff - cc_summary - Loading file from: C:\Users\andmn\AppData\Local\Temp\tmpe_rjzm_9\storage\read_component_changeouts using PickledObjectFilesystemIOManager...
# 2025-04-10 09:03:44 -0400 - dagster - DEBUG - icc_job - c140f2ca-00cd-451a-a765-1127c3d521ff - 21648 - cc_summary - LOADED_INPUT - Loaded input "read_component_changeouts" using input manager "io_manager", from output "result" of step "read_component_changeouts"
# 2025-04-10 09:03:44 -0400 - dagster - DEBUG - icc_job - c140f2ca-00cd-451a-a765-1127c3d521ff - 21648 - cc_summary - STEP_INPUT - Got input "read_component_changeouts" of type "Any". (Type check passed).
# 2025-04-10 09:03:44 -0400 - dagster - DEBUG - icc_job - c140f2ca-00cd-451a-a765-1127c3d521ff - 21648 - cc_summary - STEP_OUTPUT - Yielded output "result" of type "Any". (Type check passed).
# 2025-04-10 09:03:44 -0400 - dagster - DEBUG - icc_job - c140f2ca-00cd-451a-a765-1127c3d521ff - cc_summary - Writing file at: C:\Users\andmn\AppData\Local\Temp\tmpe_rjzm_9\storage\cc_summary using PickledObjectFilesystemIOManager...
# 2025-04-10 09:03:44 -0400 - dagster - DEBUG - icc_job - c140f2ca-00cd-451a-a765-1127c3d521ff - 21648 - cc_summary - ASSET_MATERIALIZATION - Materialized value cc_summary.
# 2025-04-10 09:03:44 -0400 - dagster - DEBUG - icc_job - c140f2ca-00cd-451a-a765-1127c3d521ff - 21648 - cc_summary - HANDLED_OUTPUT - Handled output "result" using IO manager "io_manager"
# 2025-04-10 09:03:44 -0400 - dagster - DEBUG - icc_job - c140f2ca-00cd-451a-a765-1127c3d521ff - 21648 - cc_summary - STEP_SUCCESS - Finished execution of step "cc_summary" in 102ms.
# 2025-04-10 09:03:44 -0400 - dagster - DEBUG - icc_job - c140f2ca-00cd-451a-a765-1127c3d521ff - 21648 - icc - STEP_START - Started execution of step "icc".
# 2025-04-10 09:03:44 -0400 - dagster - DEBUG - icc_job - c140f2ca-00cd-451a-a765-1127c3d521ff - icc - Loading file from: C:\Users\andmn\AppData\Local\Temp\tmpe_rjzm_9\storage\cc_summary using PickledObjectFilesystemIOManager...
# 2025-04-10 09:03:44 -0400 - dagster - DEBUG - icc_job - c140f2ca-00cd-451a-a765-1127c3d521ff - 21648 - icc - LOADED_INPUT - Loaded input "cc_summary" using input manager "io_manager", from output "result" of step "cc_summary"
# 2025-04-10 09:03:44 -0400 - dagster - DEBUG - icc_job - c140f2ca-00cd-451a-a765-1127c3d521ff - icc - Loading file from: C:\Users\andmn\AppData\Local\Temp\tmpe_rjzm_9\storage\gather_icc_reports using PickledObjectFilesystemIOManager...
# 2025-04-10 09:03:44 -0400 - dagster - DEBUG - icc_job - c140f2ca-00cd-451a-a765-1127c3d521ff - 21648 - icc - LOADED_INPUT - Loaded input "gather_icc_reports" using input manager "io_manager", from output "result" of step "gather_icc_reports"
# 2025-04-10 09:03:44 -0400 - dagster - DEBUG - icc_job - c140f2ca-00cd-451a-a765-1127c3d521ff - 21648 - icc - STEP_INPUT - Got input "cc_summary" of type "Any". (Type check passed).
# 2025-04-10 09:03:44 -0400 - dagster - DEBUG - icc_job - c140f2ca-00cd-451a-a765-1127c3d521ff - 21648 - icc - STEP_INPUT - Got input "gather_icc_reports" of type "Any". (Type check passed).
# 2025-04-10 09:03:44 -0400 - dagster - INFO - icc_job - c140f2ca-00cd-451a-a765-1127c3d521ff - icc - Writing 124 records to abfs://bhp-analytics-data/RELIABILITY/ICC/icc.parquet
# 2025-04-10 09:03:47 -0400 - dagster - DEBUG - icc_job - c140f2ca-00cd-451a-a765-1127c3d521ff - 21648 - icc - STEP_OUTPUT - Yielded output "result" of type "Any". (Type check passed).
# 2025-04-10 09:03:47 -0400 - dagster - DEBUG - icc_job - c140f2ca-00cd-451a-a765-1127c3d521ff - icc - Writing file at: C:\Users\andmn\AppData\Local\Temp\tmpe_rjzm_9\storage\icc using PickledObjectFilesystemIOManager...
# 2025-04-10 09:03:47 -0400 - dagster - DEBUG - icc_job - c140f2ca-00cd-451a-a765-1127c3d521ff - 21648 - icc - ASSET_MATERIALIZATION - Materialized value icc.
# 2025-04-10 09:03:47 -0400 - dagster - DEBUG - icc_job - c140f2ca-00cd-451a-a765-1127c3d521ff - 21648 - icc - HANDLED_OUTPUT - Handled output "result" using IO manager "io_manager"
# 2025-04-10 09:03:47 -0400 - dagster - DEBUG - icc_job - c140f2ca-00cd-451a-a765-1127c3d521ff - 21648 - icc - STEP_SUCCESS - Finished execution of step "icc" in 2.34s.
# 2025-04-10 09:03:47 -0400 - dagster - DEBUG - icc_job - c140f2ca-00cd-451a-a765-1127c3d521ff - 21648 - publish_sharepoint_icc - STEP_START - Started execution of step "publish_sharepoint_icc".
# 2025-04-10 09:03:47 -0400 - dagster - DEBUG - icc_job - c140f2ca-00cd-451a-a765-1127c3d521ff - publish_sharepoint_icc - Loading file from: C:\Users\andmn\AppData\Local\Temp\tmpe_rjzm_9\storage\icc using PickledObjectFilesystemIOManager...
# 2025-04-10 09:03:47 -0400 - dagster - DEBUG - icc_job - c140f2ca-00cd-451a-a765-1127c3d521ff - 21648 - publish_sharepoint_icc - LOADED_INPUT - Loaded input "icc" using input manager "io_manager", from output "result" of step "icc"
# 2025-04-10 09:03:47 -0400 - dagster - DEBUG - icc_job - c140f2ca-00cd-451a-a765-1127c3d521ff - 21648 - publish_sharepoint_icc - STEP_INPUT - Got input "icc" of type "DataFrame". (Type check passed).
# 2025-04-10 09:03:47 -0400 - dagster - INFO - icc_job - c140f2ca-00cd-451a-a765-1127c3d521ff - publish_sharepoint_icc - Preparing to upload 124 records to SharePoint.
# 2025-04-10 09:03:56 -0400 - dagster - INFO - icc_job - c140f2ca-00cd-451a-a765-1127c3d521ff - publish_sharepoint_icc - Successfully uploaded oil analysis data to SharePoint: https://globalkomatsu.sharepoint.com/sites/KCHCLSP00022/_layouts/15/Doc.aspx?sourcedoc=%7B1414AD4F-70B2-4261-9AF9-2CB668C43E6E%7D&file=icc.xlsx&action=default&mobileredirect=true
# 2025-04-10 09:03:56 -0400 - dagster - DEBUG - icc_job - c140f2ca-00cd-451a-a765-1127c3d521ff - 21648 - publish_sharepoint_icc - STEP_OUTPUT - Yielded output "result" of type "Any". (Type check passed).
# 2025-04-10 09:03:56 -0400 - dagster - DEBUG - icc_job - c140f2ca-00cd-451a-a765-1127c3d521ff - publish_sharepoint_icc - Writing file at: C:\Users\andmn\AppData\Local\Temp\tmpe_rjzm_9\storage\publish_sharepoint_icc using PickledObjectFilesystemIOManager...
# 2025-04-10 09:03:56 -0400 - dagster - DEBUG - icc_job - c140f2ca-00cd-451a-a765-1127c3d521ff - 21648 - publish_sharepoint_icc - ASSET_MATERIALIZATION - Materialized value publish_sharepoint_icc.
# 2025-04-10 09:03:56 -0400 - dagster - DEBUG - icc_job - c140f2ca-00cd-451a-a765-1127c3d521ff - 21648 - publish_sharepoint_icc - HANDLED_OUTPUT - Handled output "result" using IO manager "io_manager"
# 2025-04-10 09:03:56 -0400 - dagster - DEBUG - icc_job - c140f2ca-00cd-451a-a765-1127c3d521ff - 21648 - publish_sharepoint_icc - STEP_SUCCESS - Finished execution of step "publish_sharepoint_icc" in 9.28s.
# C:\Users\andmn\DataspellProjects\workspace\venv\Lib\site-packages\dagster\_core\execution\context_creation_job.py:258: RuntimeWarning: coroutine 'BaseEventLoop.shutdown_asyncgens' was never awaited
#   pass
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# 2025-04-10 09:03:56 -0400 - dagster - DEBUG - icc_job - c140f2ca-00cd-451a-a765-1127c3d521ff - 21648 - ENGINE_EVENT - Finished steps in process (pid: 21648) in 55.38s
# 2025-04-10 09:03:56 -0400 - dagster - DEBUG - icc_job - c140f2ca-00cd-451a-a765-1127c3d521ff - 21648 - RUN_SUCCESS - Finished execution of run for "icc_job".

# %%
kdefs.get_job_def("scrape_component_status_job").execute_in_process(raise_on_error=True)
# Out:
# 2025-04-10 09:36:10 -0400 - dagster - DEBUG - scrape_component_status_job - c6f94076-4d17-466f-a5bf-7710bdd0294e - 21648 - RUN_START - Started execution of run for "scrape_component_status_job".
# 2025-04-10 09:36:10 -0400 - dagster - DEBUG - scrape_component_status_job - c6f94076-4d17-466f-a5bf-7710bdd0294e - 21648 - ENGINE_EVENT - Executing steps in process (pid: 21648)
# 2025-04-10 09:36:10 -0400 - dagster - DEBUG - scrape_component_status_job - c6f94076-4d17-466f-a5bf-7710bdd0294e - 21648 - scrape_component_status - RESOURCE_INIT_STARTED - Starting initialization of resources [io_manager].
# 2025-04-10 09:36:10 -0400 - dagster - DEBUG - scrape_component_status_job - c6f94076-4d17-466f-a5bf-7710bdd0294e - 21648 - scrape_component_status - RESOURCE_INIT_SUCCESS - Finished initialization of resources [io_manager].
# 2025-04-10 09:36:10 -0400 - dagster - DEBUG - scrape_component_status_job - c6f94076-4d17-466f-a5bf-7710bdd0294e - 21648 - LOGS_CAPTURED - Started capturing logs in process (pid: 21648).
# 2025-04-10 09:36:10 -0400 - dagster - DEBUG - scrape_component_status_job - c6f94076-4d17-466f-a5bf-7710bdd0294e - 21648 - scrape_component_status - STEP_START - Started execution of step "scrape_component_status".
# 2025-04-10 09:36:10 -0400 - dagster - INFO - scrape_component_status_job - c6f94076-4d17-466f-a5bf-7710bdd0294e - scrape_component_status - Initializing WebDriver...
# Error sending stats to Plausible: error sending request for url (https://plausible.io/api/event)
# 2025-04-10 09:36:22 -0400 - dagster - INFO - scrape_component_status_job - c6f94076-4d17-466f-a5bf-7710bdd0294e - scrape_component_status - WebDriver initialized.
# 2025-04-10 09:36:22 -0400 - dagster - INFO - scrape_component_status_job - c6f94076-4d17-466f-a5bf-7710bdd0294e - scrape_component_status - Logging into RESO+...
# 2025-04-10 09:36:52 -0400 - dagster - INFO - scrape_component_status_job - c6f94076-4d17-466f-a5bf-7710bdd0294e - scrape_component_status - Login successful.
# --- Clicking Reportabilidad ---
# Clicked 'Reportabilidad'.
# 2025-04-10 09:37:01 -0400 - dagster - INFO - scrape_component_status_job - c6f94076-4d17-466f-a5bf-7710bdd0294e - scrape_component_status - Navigated to Estatus Componente page.
# 2025-04-10 09:37:04 -0400 - dagster - INFO - scrape_component_status_job - c6f94076-4d17-466f-a5bf-7710bdd0294e - scrape_component_status - Default filters applied.
# 2025-04-10 09:37:04 -0400 - dagster - INFO - scrape_component_status_job - c6f94076-4d17-466f-a5bf-7710bdd0294e - scrape_component_status - Starting year loop from 2025 down to 2005...
# 2025-04-10 09:37:04 -0400 - dagster - INFO - scrape_component_status_job - c6f94076-4d17-466f-a5bf-7710bdd0294e - scrape_component_status - Processing Year: 2025
# --- Setting Dates: 01-01-2025 to 31-12-2025 ---
# Setting 'Date From': 01-01-2025
#   Target Day: 1
#   Clicking calendar icon using JavaScript...
#   Sent keys '01-01-2025' to input field.
#   Input value confirmed.
#   Calendar widget is visible.
#   Looking for day '1' link within the calendar widget...
#   Found day '1' element. Now waiting for it to be clickable...
#   Day '1' is clickable.
#   Clicked day '1' in calendar for 'Date From'.
#   Calendar widget closed.
# Setting 'Date Up': 31-12-2025
#   Target Day: 31
#   Clicking calendar icon using JavaScript...
#   Sent keys '31-12-2025' to input field.
#   Input value confirmed.
#   Calendar widget is visible.
#   Looking for day '31' link within the calendar widget...
#   Found day '31' element. Now waiting for it to be clickable...
#   Day '31' is clickable.
#   Clicked day '31' in calendar for 'Date Up'.
#   Calendar widget closed.
#
# Finished setting dates: 01-01-2025 to 31-12-2025
# --- Uploading results for year 2025 to abfs://bhp-raw-data/RESO/COMPONENT_STATUS/y=2025/m=04/d=10/component_status_2025.parquet ---
# 2025-04-10 09:37:26 -0400 - dagster - INFO - scrape_component_status_job - c6f94076-4d17-466f-a5bf-7710bdd0294e - scrape_component_status - Checking for downloads in: C:\Users\andmn\Downloads
# 2025-04-10 09:37:27 -0400 - dagster - INFO - scrape_component_status_job - c6f94076-4d17-466f-a5bf-7710bdd0294e - scrape_component_status - Identified most recent Excel file: C:\Users\andmn\Downloads\Components Status.xls
# 2025-04-10 09:37:29 -0400 - dagster - INFO - scrape_component_status_job - c6f94076-4d17-466f-a5bf-7710bdd0294e - scrape_component_status - Successfully read data from Components Status.xls
# 2025-04-10 09:37:32 -0400 - dagster - INFO - scrape_component_status_job - c6f94076-4d17-466f-a5bf-7710bdd0294e - scrape_component_status - Successfully uploaded data for year 2025 to abfs://bhp-raw-data/RESO/COMPONENT_STATUS/y=2025/m=04/d=10/component_status_2025.parquet
# 2025-04-10 09:37:32 -0400 - dagster - INFO - scrape_component_status_job - c6f94076-4d17-466f-a5bf-7710bdd0294e - scrape_component_status - Deleting local file: C:\Users\andmn\Downloads\Components Status.xls
# 2025-04-10 09:37:32 -0400 - dagster - INFO - scrape_component_status_job - c6f94076-4d17-466f-a5bf-7710bdd0294e - scrape_component_status - Deleted local file: Components Status.xls
# 2025-04-10 09:37:32 -0400 - dagster - INFO - scrape_component_status_job - c6f94076-4d17-466f-a5bf-7710bdd0294e - scrape_component_status - Processing Year: 2024
# --- Setting Dates: 01-01-2024 to 31-12-2024 ---
# Setting 'Date From': 01-01-2024
#   Target Day: 1
#   Clicking calendar icon using JavaScript...
#   Sent keys '01-01-2024' to input field.
#   Input value confirmed.
#   Calendar widget is visible.
#   Looking for day '1' link within the calendar widget...
#   Found day '1' element. Now waiting for it to be clickable...
#   Day '1' is clickable.
#   Clicked day '1' in calendar for 'Date From'.
#   Calendar widget closed.
# Setting 'Date Up': 31-12-2024
#   Target Day: 31
#   Clicking calendar icon using JavaScript...
#   Sent keys '31-12-2024' to input field.
#   Input value confirmed.
#   Calendar widget is visible.
#   Looking for day '31' link within the calendar widget...
#   Found day '31' element. Now waiting for it to be clickable...
#   Day '31' is clickable.
#   Clicked day '31' in calendar for 'Date Up'.
#   Calendar widget closed.
#
# Finished setting dates: 01-01-2024 to 31-12-2024
# --- Uploading results for year 2024 to abfs://bhp-raw-data/RESO/COMPONENT_STATUS/y=2025/m=04/d=10/component_status_2024.parquet ---
# 2025-04-10 09:40:15 -0400 - dagster - INFO - scrape_component_status_job - c6f94076-4d17-466f-a5bf-7710bdd0294e - scrape_component_status - Checking for downloads in: C:\Users\andmn\Downloads
# 2025-04-10 09:40:16 -0400 - dagster - INFO - scrape_component_status_job - c6f94076-4d17-466f-a5bf-7710bdd0294e - scrape_component_status - Identified most recent Excel file: C:\Users\andmn\Downloads\Components Status.xls
# 2025-04-10 09:40:21 -0400 - dagster - INFO - scrape_component_status_job - c6f94076-4d17-466f-a5bf-7710bdd0294e - scrape_component_status - Successfully read data from Components Status.xls
# 2025-04-10 09:40:25 -0400 - dagster - INFO - scrape_component_status_job - c6f94076-4d17-466f-a5bf-7710bdd0294e - scrape_component_status - Successfully uploaded data for year 2024 to abfs://bhp-raw-data/RESO/COMPONENT_STATUS/y=2025/m=04/d=10/component_status_2024.parquet
# 2025-04-10 09:40:25 -0400 - dagster - INFO - scrape_component_status_job - c6f94076-4d17-466f-a5bf-7710bdd0294e - scrape_component_status - Deleting local file: C:\Users\andmn\Downloads\Components Status.xls
# 2025-04-10 09:40:25 -0400 - dagster - INFO - scrape_component_status_job - c6f94076-4d17-466f-a5bf-7710bdd0294e - scrape_component_status - Deleted local file: Components Status.xls
# 2025-04-10 09:40:25 -0400 - dagster - INFO - scrape_component_status_job - c6f94076-4d17-466f-a5bf-7710bdd0294e - scrape_component_status - Processing Year: 2023
# --- Setting Dates: 01-01-2023 to 31-12-2023 ---
# Setting 'Date From': 01-01-2023
#   Target Day: 1
#   Clicking calendar icon using JavaScript...
#   Sent keys '01-01-2023' to input field.
#   Input value confirmed.
#   Calendar widget is visible.
#   Looking for day '1' link within the calendar widget...
#   Found day '1' element. Now waiting for it to be clickable...
#   Day '1' is clickable.
#   Clicked day '1' in calendar for 'Date From'.
#   Calendar widget closed.
# Setting 'Date Up': 31-12-2023
#   Target Day: 31
#   Clicking calendar icon using JavaScript...
#   Sent keys '31-12-2023' to input field.
#   Input value confirmed.
#   Calendar widget is visible.
#   Looking for day '31' link within the calendar widget...
#   Found day '31' element. Now waiting for it to be clickable...
#   Day '31' is clickable.
#   Clicked day '31' in calendar for 'Date Up'.
#   Calendar widget closed.
#
# Finished setting dates: 01-01-2023 to 31-12-2023
# 2025-04-10 09:43:17 -0400 - dagster - ERROR - scrape_component_status_job - c6f94076-4d17-466f-a5bf-7710bdd0294e - 21648 - scrape_component_status - STEP_FAILURE - Execution of step "scrape_component_status" failed.
#
# dagster._core.errors.DagsterExecutionStepExecutionError: Error occurred while executing op "scrape_component_status"::
#
# urllib3.exceptions.ReadTimeoutError: HTTPConnectionPool(host='localhost', port=53104): Read timed out. (read timeout=120)
#
# Stack Trace:
#   File "C:\Users\andmn\DataspellProjects\workspace\venv\Lib\site-packages\dagster\_core\execution\plan\utils.py", line 56, in op_execution_error_boundary
#     yield
#   File "C:\Users\andmn\DataspellProjects\workspace\venv\Lib\site-packages\dagster\_utils\__init__.py", line 391, in iterate_with_context
#     next_output = next(iterator)
#                   ^^^^^^^^^^^^^^
#   File "C:\Users\andmn\DataspellProjects\workspace\venv\Lib\site-packages\dagster\_core\execution\plan\compute_generator.py", line 127, in _coerce_op_compute_fn_to_iterator
#     result = invoke_compute_fn(
#              ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\andmn\DataspellProjects\workspace\venv\Lib\site-packages\dagster\_core\execution\plan\compute_generator.py", line 115, in invoke_compute_fn
#     return fn(context, **args_to_pass) if context_arg_provided else fn(**args_to_pass)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\andmn\DataspellProjects\kverse\kdags\assets\reparation\reso\component_status_scraper.py", line 332, in scrape_component_status
#     export_component_status_results(driver, wait)
#   File "C:\Users\andmn\DataspellProjects\kverse\kdags\assets\reparation\reso\component_status_scraper.py", line 229, in export_component_status_results
#     export_button.click()
#   File "C:\Users\andmn\DataspellProjects\workspace\venv\Lib\site-packages\selenium\webdriver\remote\webelement.py", line 119, in click
#     self._execute(Command.CLICK_ELEMENT)
#   File "C:\Users\andmn\DataspellProjects\workspace\venv\Lib\site-packages\selenium\webdriver\remote\webelement.py", line 572, in _execute
#     return self._parent.execute(command, params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\andmn\DataspellProjects\workspace\venv\Lib\site-packages\selenium\webdriver\remote\webdriver.py", line 427, in execute
#     response = self.command_executor.execute(driver_command, params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\andmn\DataspellProjects\workspace\venv\Lib\site-packages\selenium\webdriver\remote\remote_connection.py", line 404, in execute
#     return self._request(command_info[0], url, body=data)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\andmn\DataspellProjects\workspace\venv\Lib\site-packages\selenium\webdriver\remote\remote_connection.py", line 428, in _request
#     response = self._conn.request(method, url, body=body, headers=headers, timeout=self._client_config.timeout)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\andmn\DataspellProjects\workspace\venv\Lib\site-packages\urllib3\_request_methods.py", line 143, in request
#     return self.request_encode_body(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\andmn\DataspellProjects\workspace\venv\Lib\site-packages\urllib3\_request_methods.py", line 278, in request_encode_body
#     return self.urlopen(method, url, **extra_kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\andmn\DataspellProjects\workspace\venv\Lib\site-packages\urllib3\poolmanager.py", line 443, in urlopen
#     response = conn.urlopen(method, u.request_uri, **kw)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\andmn\DataspellProjects\workspace\venv\Lib\site-packages\urllib3\connectionpool.py", line 841, in urlopen
#     retries = retries.increment(
#               ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\andmn\DataspellProjects\workspace\venv\Lib\site-packages\urllib3\util\retry.py", line 474, in increment
#     raise reraise(type(error), error, _stacktrace)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\andmn\DataspellProjects\workspace\venv\Lib\site-packages\urllib3\util\util.py", line 39, in reraise
#     raise value
#   File "C:\Users\andmn\DataspellProjects\workspace\venv\Lib\site-packages\urllib3\connectionpool.py", line 787, in urlopen
#     response = self._make_request(
#                ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\andmn\DataspellProjects\workspace\venv\Lib\site-packages\urllib3\connectionpool.py", line 536, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "C:\Users\andmn\DataspellProjects\workspace\venv\Lib\site-packages\urllib3\connectionpool.py", line 367, in _raise_timeout
#     raise ReadTimeoutError(
#
# The above exception was caused by the following exception:
# TimeoutError: timed out
#
# Stack Trace:
#   File "C:\Users\andmn\DataspellProjects\workspace\venv\Lib\site-packages\urllib3\connectionpool.py", line 534, in _make_request
#     response = conn.getresponse()
#                ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\andmn\DataspellProjects\workspace\venv\Lib\site-packages\urllib3\connection.py", line 516, in getresponse
#     httplib_response = super().getresponse()
#                        ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0\Lib\http\client.py", line 1430, in getresponse
#     response.begin()
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0\Lib\http\client.py", line 331, in begin
#     version, status, reason = self._read_status()
#                               ^^^^^^^^^^^^^^^^^^^
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0\Lib\http\client.py", line 292, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0\Lib\socket.py", line 720, in readinto
#     return self._sock.recv_into(b)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#
# C:\Users\andmn\DataspellProjects\workspace\venv\Lib\site-packages\dagster\_core\execution\context_creation_job.py:258: RuntimeWarning: coroutine 'BaseEventLoop.shutdown_asyncgens' was never awaited
#   pass
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# 2025-04-10 09:43:17 -0400 - dagster - ERROR - scrape_component_status_job - c6f94076-4d17-466f-a5bf-7710bdd0294e - 21648 - RUN_FAILURE - Execution of run for "scrape_component_status_job" failed. An exception was thrown during execution.
#
# urllib3.exceptions.ReadTimeoutError: HTTPConnectionPool(host='localhost', port=53104): Read timed out. (read timeout=120)
#
# Stack Trace:
#   File "C:\Users\andmn\DataspellProjects\workspace\venv\Lib\site-packages\dagster\_core\execution\api.py", line 736, in job_execution_iterator
#     for event in job_context.executor.execute(job_context, execution_plan):
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\andmn\DataspellProjects\workspace\venv\Lib\site-packages\dagster\_core\executor\in_process.py", line 55, in execute
#     yield from iter(
#   File "C:\Users\andmn\DataspellProjects\workspace\venv\Lib\site-packages\dagster\_core\execution\api.py", line 869, in __iter__
#     yield from self.iterator(
#   File "C:\Users\andmn\DataspellProjects\workspace\venv\Lib\site-packages\dagster\_core\executor\in_process.py", line 26, in inprocess_execution_iterator
#     yield from inner_plan_execution_iterator(
#   File "C:\Users\andmn\DataspellProjects\workspace\venv\Lib\site-packages\dagster\_core\execution\plan\execute_plan.py", line 87, in inner_plan_execution_iterator
#     for step_event in check.generator(dagster_event_sequence_for_step(step_context)):
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\andmn\DataspellProjects\workspace\venv\Lib\site-packages\dagster\_core\execution\plan\execute_plan.py", line 317, in dagster_event_sequence_for_step
#     raise dagster_user_error.user_exception
#   File "C:\Users\andmn\DataspellProjects\workspace\venv\Lib\site-packages\dagster\_core\execution\plan\utils.py", line 56, in op_execution_error_boundary
#     yield
#   File "C:\Users\andmn\DataspellProjects\workspace\venv\Lib\site-packages\dagster\_utils\__init__.py", line 391, in iterate_with_context
#     next_output = next(iterator)
#                   ^^^^^^^^^^^^^^
#   File "C:\Users\andmn\DataspellProjects\workspace\venv\Lib\site-packages\dagster\_core\execution\plan\compute_generator.py", line 127, in _coerce_op_compute_fn_to_iterator
#     result = invoke_compute_fn(
#              ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\andmn\DataspellProjects\workspace\venv\Lib\site-packages\dagster\_core\execution\plan\compute_generator.py", line 115, in invoke_compute_fn
#     return fn(context, **args_to_pass) if context_arg_provided else fn(**args_to_pass)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\andmn\DataspellProjects\kverse\kdags\assets\reparation\reso\component_status_scraper.py", line 332, in scrape_component_status
#     export_component_status_results(driver, wait)
#   File "C:\Users\andmn\DataspellProjects\kverse\kdags\assets\reparation\reso\component_status_scraper.py", line 229, in export_component_status_results
#     export_button.click()
#   File "C:\Users\andmn\DataspellProjects\workspace\venv\Lib\site-packages\selenium\webdriver\remote\webelement.py", line 119, in click
#     self._execute(Command.CLICK_ELEMENT)
#   File "C:\Users\andmn\DataspellProjects\workspace\venv\Lib\site-packages\selenium\webdriver\remote\webelement.py", line 572, in _execute
#     return self._parent.execute(command, params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\andmn\DataspellProjects\workspace\venv\Lib\site-packages\selenium\webdriver\remote\webdriver.py", line 427, in execute
#     response = self.command_executor.execute(driver_command, params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\andmn\DataspellProjects\workspace\venv\Lib\site-packages\selenium\webdriver\remote\remote_connection.py", line 404, in execute
#     return self._request(command_info[0], url, body=data)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\andmn\DataspellProjects\workspace\venv\Lib\site-packages\selenium\webdriver\remote\remote_connection.py", line 428, in _request
#     response = self._conn.request(method, url, body=body, headers=headers, timeout=self._client_config.timeout)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\andmn\DataspellProjects\workspace\venv\Lib\site-packages\urllib3\_request_methods.py", line 143, in request
#     return self.request_encode_body(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\andmn\DataspellProjects\workspace\venv\Lib\site-packages\urllib3\_request_methods.py", line 278, in request_encode_body
#     return self.urlopen(method, url, **extra_kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\andmn\DataspellProjects\workspace\venv\Lib\site-packages\urllib3\poolmanager.py", line 443, in urlopen
#     response = conn.urlopen(method, u.request_uri, **kw)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\andmn\DataspellProjects\workspace\venv\Lib\site-packages\urllib3\connectionpool.py", line 841, in urlopen
#     retries = retries.increment(
#               ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\andmn\DataspellProjects\workspace\venv\Lib\site-packages\urllib3\util\retry.py", line 474, in increment
#     raise reraise(type(error), error, _stacktrace)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\andmn\DataspellProjects\workspace\venv\Lib\site-packages\urllib3\util\util.py", line 39, in reraise
#     raise value
#   File "C:\Users\andmn\DataspellProjects\workspace\venv\Lib\site-packages\urllib3\connectionpool.py", line 787, in urlopen
#     response = self._make_request(
#                ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\andmn\DataspellProjects\workspace\venv\Lib\site-packages\urllib3\connectionpool.py", line 536, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "C:\Users\andmn\DataspellProjects\workspace\venv\Lib\site-packages\urllib3\connectionpool.py", line 367, in _raise_timeout
#     raise ReadTimeoutError(
#
# The above exception was caused by the following exception:
# TimeoutError: timed out
#
# Stack Trace:
#   File "C:\Users\andmn\DataspellProjects\workspace\venv\Lib\site-packages\urllib3\connectionpool.py", line 534, in _make_request
#     response = conn.getresponse()
#                ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\andmn\DataspellProjects\workspace\venv\Lib\site-packages\urllib3\connection.py", line 516, in getresponse
#     httplib_response = super().getresponse()
#                        ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0\Lib\http\client.py", line 1430, in getresponse
#     response.begin()
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0\Lib\http\client.py", line 331, in begin
#     version, status, reason = self._read_status()
#                               ^^^^^^^^^^^^^^^^^^^
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0\Lib\http\client.py", line 292, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0\Lib\socket.py", line 720, in readinto
#     return self._sock.recv_into(b)
#            ^^^^^^^^^^^^^^^^^^^^^^^
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~\DataspellProjects\workspace\venv\Lib\site-packages\urllib3\connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#
# File ~\DataspellProjects\workspace\venv\Lib\site-packages\urllib3\connection.py:516, in HTTPConnection.getresponse(self)
#     515 # Get the response from http.client.HTTPConnection
# --> 516 httplib_response = super().getresponse()
#     518 try:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0\Lib\http\client.py:1430, in HTTPConnection.getresponse(self)
#    1429 try:
# -> 1430     response.begin()
#    1431 except ConnectionError:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0\Lib\http\client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0\Lib\socket.py:720, in SocketIO.readinto(self, b)
#     719 try:
# --> 720     return self._sock.recv_into(b)
#     721 except timeout:
#
# TimeoutError: timed out
#
# The above exception was the direct cause of the following exception:
#
# ReadTimeoutError                          Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 kdefs.get_job_def("scrape_component_status_job").execute_in_process(raise_on_error=True)
#
# File ~\DataspellProjects\workspace\venv\Lib\site-packages\dagster\_core\definitions\job_definition.py:745, in JobDefinition.execute_in_process(self, run_config, instance, partition_key, raise_on_error, op_selection, asset_selection, run_id, input_values, tags, resources)
#     742     else:
#     743         merged_run_tags.update(tags_for_partition_key)
# --> 745 return core_execute_in_process(
#     746     ephemeral_job=ephemeral_job,
#     747     run_config=run_config,
#     748     instance=instance,
#     749     output_capturing_enabled=True,
#     750     raise_on_error=raise_on_error,
#     751     run_tags=merged_run_tags,
#     752     run_id=run_id,
#     753     asset_selection=frozenset(asset_selection),
#     754 )
#
# File ~\DataspellProjects\workspace\venv\Lib\site-packages\dagster\_core\execution\execute_in_process.py:76, in core_execute_in_process(run_config, ephemeral_job, instance, output_capturing_enabled, raise_on_error, run_tags, run_id, asset_selection)
#      59     run_id = run.run_id
#      61     execute_run_iterable = ExecuteRunWithPlanIterable(
#      62         execution_plan=execution_plan,
#      63         iterator=job_execution_iterator,
#    (...)     74         ),
#      75     )
# ---> 76     event_list = list(execute_run_iterable)
#      77     run = execute_instance.get_run_by_id(run_id)
#      79 return ExecuteInProcessResult(
#      80     job_def=ephemeral_job,
#      81     event_list=event_list,
#      82     dagster_run=cast(DagsterRun, run),
#      83     output_capture=output_capture,
#      84 )
#
# File ~\DataspellProjects\workspace\venv\Lib\site-packages\dagster\_core\execution\api.py:869, in ExecuteRunWithPlanIterable.__iter__(self)
#     867 try:
#     868     if self.job_context:  # False if we had a pipeline init failure
# --> 869         yield from self.iterator(
#     870             execution_plan=self.execution_plan,
#     871             job_context=self.job_context,
#     872         )
#     873 except GeneratorExit:
#     874     # Shouldn't happen, but avoid runtime-exception in case this generator gets GC-ed
#     875     # (see https://amir.rachum.com/blog/2017/03/03/generator-cleanup/).
#     876     generator_closed = True
#
# File ~\DataspellProjects\workspace\venv\Lib\site-packages\dagster\_core\execution\api.py:736, in job_execution_iterator(job_context, execution_plan)
#     734 generator_closed = False
#     735 try:
# --> 736     for event in job_context.executor.execute(job_context, execution_plan):
#     737         if event.is_step_failure:
#     738             failed_steps.append(event)
#
# File ~\DataspellProjects\workspace\venv\Lib\site-packages\dagster\_core\executor\in_process.py:55, in InProcessExecutor.execute(self, plan_context, execution_plan)
#      48 yield DagsterEvent.engine_event(
#      49     plan_context,
#      50     f"Executing steps in process (pid: {os.getpid()})",
#      51     event_specific_data=EngineEventData.in_process(os.getpid(), step_keys_to_execute),
#      52 )
#      54 with time_execution_scope() as timer_result:
# ---> 55     yield from iter(
#      56         ExecuteRunWithPlanIterable(
#      57             execution_plan=plan_context.execution_plan,
#      58             iterator=inprocess_execution_iterator,
#      59             execution_context_manager=PlanExecutionContextManager(
#      60                 job=plan_context.job,
#      61                 retry_mode=plan_context.retry_mode,
#      62                 execution_plan=plan_context.execution_plan,
#      63                 run_config=plan_context.run_config,
#      64                 dagster_run=plan_context.dagster_run,
#      65                 instance=plan_context.instance,
#      66                 raise_on_error=plan_context.raise_on_error,
#      67                 output_capture=plan_context.output_capture,
#      68             ),
#      69         )
#      70     )
#      72 yield DagsterEvent.engine_event(
#      73     plan_context,
#      74     f"Finished steps in process (pid: {os.getpid()}) in {format_duration(timer_result.millis)}",
#      75     event_specific_data=EngineEventData.in_process(os.getpid(), step_keys_to_execute),
#      76 )
#
# File ~\DataspellProjects\workspace\venv\Lib\site-packages\dagster\_core\execution\api.py:869, in ExecuteRunWithPlanIterable.__iter__(self)
#     867 try:
#     868     if self.job_context:  # False if we had a pipeline init failure
# --> 869         yield from self.iterator(
#     870             execution_plan=self.execution_plan,
#     871             job_context=self.job_context,
#     872         )
#     873 except GeneratorExit:
#     874     # Shouldn't happen, but avoid runtime-exception in case this generator gets GC-ed
#     875     # (see https://amir.rachum.com/blog/2017/03/03/generator-cleanup/).
#     876     generator_closed = True
#
# File ~\DataspellProjects\workspace\venv\Lib\site-packages\dagster\_core\executor\in_process.py:26, in inprocess_execution_iterator(job_context, execution_plan, instance_concurrency_context)
#      18 def inprocess_execution_iterator(
#      19     job_context: PlanExecutionContext,
#      20     execution_plan: ExecutionPlan,
#      21     instance_concurrency_context: Optional[InstanceConcurrencyContext] = None,
#      22 ) -> Iterator[DagsterEvent]:
#      23     with InstanceConcurrencyContext(
#      24         job_context.instance, job_context.dagster_run
#      25     ) as instance_concurrency_context:
# ---> 26         yield from inner_plan_execution_iterator(
#      27             job_context, execution_plan, instance_concurrency_context
#      28         )
#
# File ~\DataspellProjects\workspace\venv\Lib\site-packages\dagster\_core\execution\plan\execute_plan.py:87, in inner_plan_execution_iterator(job_context, execution_plan, instance_concurrency_context)
#      78 check.invariant(
#      79     len(missing_resources) == 0,
#      80     (
#    (...)     83     ),
#      84 )
#      86 # we have already set up the log capture at the process level, just handle the step events
# ---> 87 for step_event in check.generator(dagster_event_sequence_for_step(step_context)):
#      88     dagster_event = check.inst(step_event, DagsterEvent)
#      89     step_event_list.append(dagster_event)
#
# File ~\DataspellProjects\workspace\venv\Lib\site-packages\dagster\_core\execution\plan\execute_plan.py:317, in dagster_event_sequence_for_step(step_context, force_local_execution)
#     310     yield step_failure_event_from_exc_info(
#     311         step_context,
#     312         sys.exc_info(),
#     313         error_source=ErrorSource.USER_CODE_ERROR,
#     314     )
#     316     if step_context.raise_on_error:
# --> 317         raise dagster_user_error.user_exception
#     319 # case (4) in top comment
#     320 except (KeyboardInterrupt, DagsterExecutionInterruptedError) as interrupt_error:
#
# File ~\DataspellProjects\workspace\venv\Lib\site-packages\dagster\_core\execution\plan\utils.py:56, in op_execution_error_boundary(error_cls, msg_fn, step_context, **kwargs)
#      53 retry_policy = step_context.op_retry_policy
#      55 try:
# ---> 56     yield
#      57 except DagsterError as de:
#      58     # The system has thrown an error that is part of the user-framework contract
#      59     raise de
#
# File ~\DataspellProjects\workspace\venv\Lib\site-packages\dagster\_utils\__init__.py:391, in iterate_with_context(context_fn, iterator)
#     389 with context_fn():
#     390     try:
# --> 391         next_output = next(iterator)
#     392     except StopIteration:
#     393         return
#
# File ~\DataspellProjects\workspace\venv\Lib\site-packages\dagster\_core\execution\plan\compute_generator.py:127, in _coerce_op_compute_fn_to_iterator(fn, output_defs, context, context_arg_provided, kwargs, config_arg_class, resource_arg_mapping)
#     118 def _coerce_op_compute_fn_to_iterator(
#     119     fn,
#     120     output_defs,
#    (...)    125     resource_arg_mapping,
#     126 ):
# --> 127     result = invoke_compute_fn(
#     128         fn, context, kwargs, context_arg_provided, config_arg_class, resource_arg_mapping
#     129     )
#     130     yield from validate_and_coerce_op_result_to_iterator(result, context, output_defs)
#
# File ~\DataspellProjects\workspace\venv\Lib\site-packages\dagster\_core\execution\plan\compute_generator.py:115, in invoke_compute_fn(fn, context, kwargs, context_arg_provided, config_arg_cls, resource_args)
#     112     for resource_name, arg_name in resource_args.items():
#     113         args_to_pass[arg_name] = context.resources.original_resource_dict[resource_name]
# --> 115 return fn(context, **args_to_pass) if context_arg_provided else fn(**args_to_pass)
#
# File ~\DataspellProjects\kverse\kdags\assets\reparation\reso\component_status_scraper.py:332, in scrape_component_status(context)
#     329 set_component_status_dates(driver, wait, start_date_str, end_date_str)
#     331 # Export the results for the current year
# --> 332 export_component_status_results(driver, wait)
#     334 # Define upload URI for the current year
#     335 # Using current_date for partition, but year for filename seems intended
#     336 partition_path = current_date.strftime("y=%Y/m=%m/d=%d")  # Partition based on run date
#
# File ~\DataspellProjects\kverse\kdags\assets\reparation\reso\component_status_scraper.py:229, in export_component_status_results(driver, wait)
#     227 export_button = wait.until(EC.presence_of_element_located(export_button_locator))
#     228 wait.until(EC.element_to_be_clickable(export_button_locator))
# --> 229 export_button.click()
#     230 time.sleep(5)
#
# File ~\DataspellProjects\workspace\venv\Lib\site-packages\selenium\webdriver\remote\webelement.py:119, in WebElement.click(self)
#     111 def click(self) -> None:
#     112     """Clicks the element.
#     113
#     114     Example:
#    (...)    117     >>> element.click()
#     118     """
# --> 119     self._execute(Command.CLICK_ELEMENT)
#
# File ~\DataspellProjects\workspace\venv\Lib\site-packages\selenium\webdriver\remote\webelement.py:572, in WebElement._execute(self, command, params)
#     570     params = {}
#     571 params["id"] = self._id
# --> 572 return self._parent.execute(command, params)
#
# File ~\DataspellProjects\workspace\venv\Lib\site-packages\selenium\webdriver\remote\webdriver.py:427, in WebDriver.execute(self, driver_command, params)
#     424     elif "sessionId" not in params:
#     425         params["sessionId"] = self.session_id
# --> 427 response = self.command_executor.execute(driver_command, params)
#     428 if response:
#     429     self.error_handler.check_response(response)
#
# File ~\DataspellProjects\workspace\venv\Lib\site-packages\selenium\webdriver\remote\remote_connection.py:404, in RemoteConnection.execute(self, command, params)
#     402 trimmed = self._trim_large_entries(params)
#     403 LOGGER.debug("%s %s %s", command_info[0], url, str(trimmed))
# --> 404 return self._request(command_info[0], url, body=data)
#
# File ~\DataspellProjects\workspace\venv\Lib\site-packages\selenium\webdriver\remote\remote_connection.py:428, in RemoteConnection._request(self, method, url, body)
#     425     body = None
#     427 if self._client_config.keep_alive:
# --> 428     response = self._conn.request(method, url, body=body, headers=headers, timeout=self._client_config.timeout)
#     429     statuscode = response.status
#     430 else:
#
# File ~\DataspellProjects\workspace\venv\Lib\site-packages\urllib3\_request_methods.py:143, in RequestMethods.request(self, method, url, body, fields, headers, json, **urlopen_kw)
#     135     return self.request_encode_url(
#     136         method,
#     137         url,
#    (...)    140         **urlopen_kw,
#     141     )
#     142 else:
# --> 143     return self.request_encode_body(
#     144         method, url, fields=fields, headers=headers, **urlopen_kw
#     145     )
#
# File ~\DataspellProjects\workspace\venv\Lib\site-packages\urllib3\_request_methods.py:278, in RequestMethods.request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     274     extra_kw["headers"].setdefault("Content-Type", content_type)
#     276 extra_kw.update(urlopen_kw)
# --> 278 return self.urlopen(method, url, **extra_kw)
#
# File ~\DataspellProjects\workspace\venv\Lib\site-packages\urllib3\poolmanager.py:443, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     441     response = conn.urlopen(method, url, **kw)
#     442 else:
# --> 443     response = conn.urlopen(method, u.request_uri, **kw)
#     445 redirect_location = redirect and response.get_redirect_location()
#     446 if not redirect_location:
#
# File ~\DataspellProjects\workspace\venv\Lib\site-packages\urllib3\connectionpool.py:841, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     838 elif isinstance(new_e, (OSError, HTTPException)):
#     839     new_e = ProtocolError("Connection aborted.", new_e)
# --> 841 retries = retries.increment(
#     842     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     843 )
#     844 retries.sleep()
#     846 # Keep track of the error for the retry warning.
#
# File ~\DataspellProjects\workspace\venv\Lib\site-packages\urllib3\util\retry.py:474, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     471 elif error and self._is_read_error(error):
#     472     # Read retry?
#     473     if read is False or method is None or not self._is_method_retryable(method):
# --> 474         raise reraise(type(error), error, _stacktrace)
#     475     elif read is not None:
#     476         read -= 1
#
# File ~\DataspellProjects\workspace\venv\Lib\site-packages\urllib3\util\util.py:39, in reraise(tp, value, tb)
#      37     if value.__traceback__ is not tb:
#      38         raise value.with_traceback(tb)
# ---> 39     raise value
#      40 finally:
#      41     value = None  # type: ignore[assignment]
#
# File ~\DataspellProjects\workspace\venv\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~\DataspellProjects\workspace\venv\Lib\site-packages\urllib3\connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
# --> 536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#     537     raise
#     539 # Set properties that are used by the pooling layer.
#
# File ~\DataspellProjects\workspace\venv\Lib\site-packages\urllib3\connectionpool.py:367, in HTTPConnectionPool._raise_timeout(self, err, url, timeout_value)
#     364 """Is the error actually a timeout? Will raise a ReadTimeout or pass"""
#     366 if isinstance(err, SocketTimeout):
# --> 367     raise ReadTimeoutError(
#     368         self, url, f"Read timed out. (read timeout={timeout_value})"
#     369     ) from err
#     371 # See the above comment about EAGAIN in Python 3.
#     372 if hasattr(err, "errno") and err.errno in _blocking_errnos:
#
# ReadTimeoutError: HTTPConnectionPool(host='localhost', port=53104): Read timed out. (read timeout=120)

# %%
df = result.asset_value("icc").clone()
df
# Out:
# shape: (124, 16)
# ┌────────────┬────────────┬────────────┬────────────┬───┬────────────┬──────────┬──────────┬───────┐
# │ equipment_ ┆ equipment_ ┆ equipment_ ┆ component_ ┆ … ┆ failure_de ┆ iso_year ┆ iso_week ┆ shift │
# │ name       ┆ hours      ┆ hours_icc  ┆ name       ┆   ┆ scription  ┆ ---      ┆ ---      ┆ ---   │
# │ ---        ┆ ---        ┆ ---        ┆ ---        ┆   ┆ ---        ┆ i32      ┆ i8       ┆ str   │
# │ str        ┆ i64        ┆ f64        ┆ str        ┆   ┆ str        ┆          ┆          ┆       │
# ╞════════════╪════════════╪════════════╪════════════╪═══╪════════════╪══════════╪══════════╪═══════╡
# │ null       ┆ null       ┆ 53.281     ┆ null       ┆ … ┆ null       ┆ null     ┆ null     ┆ null  │
# │ null       ┆ null       ┆ 66539.0    ┆ null       ┆ … ┆ null       ┆ null     ┆ null     ┆ null  │
# │ null       ┆ null       ┆ 74693.0    ┆ null       ┆ … ┆ null       ┆ null     ┆ null     ┆ null  │
# │ TK857      ┆ 74693      ┆ null       ┆ modulo_pot ┆ … ┆ Se procede ┆ 2025     ┆ 15       ┆ N     │
# │            ┆            ┆            ┆ encia      ┆   ┆ a cambio   ┆          ┆          ┆       │
# │            ┆            ┆            ┆            ┆   ┆ de modulo  ┆          ┆          ┆       │
# │            ┆            ┆            ┆            ┆   ┆ …          ┆          ┆          ┆       │
# │ TK862      ┆ 65500      ┆ 65500.0    ┆ cilindro_d ┆ … ┆ Se procede ┆ 2025     ┆ 14       ┆ N     │
# │            ┆            ┆            ┆ ireccion   ┆   ┆ a cambio   ┆          ┆          ┆       │
# │            ┆            ┆            ┆            ┆   ┆ de         ┆          ┆          ┆       │
# │            ┆            ┆            ┆            ┆   ┆ cilindr…   ┆          ┆          ┆       │
# │ …          ┆ …          ┆ …          ┆ …          ┆ … ┆ …          ┆ …        ┆ …        ┆ …     │
# │ TK291      ┆ 26062      ┆ null       ┆ blower_par ┆ … ┆ Se procede ┆ 2024     ┆ 40       ┆ N     │
# │            ┆            ┆            ┆ rilla      ┆   ┆ a cambio   ┆          ┆          ┆       │
# │            ┆            ┆            ┆            ┆   ┆ de blower  ┆          ┆          ┆       │
# │            ┆            ┆            ┆            ┆   ┆ …          ┆          ┆          ┆       │
# │ TK855      ┆ 67049      ┆ 67.049     ┆ blower_par ┆ … ┆ Se procede ┆ 2024     ┆ 40       ┆ M     │
# │            ┆            ┆            ┆ rilla      ┆   ┆ a cambio   ┆          ┆          ┆       │
# │            ┆            ┆            ┆            ┆   ┆ de Blower  ┆          ┆          ┆       │
# │            ┆            ┆            ┆            ┆   ┆ …          ┆          ┆          ┆       │
# │ TK867      ┆ 62824      ┆ 62.824     ┆ suspension ┆ … ┆ Se procede ┆ 2024     ┆ 39       ┆ M     │
# │            ┆            ┆            ┆ _trasera   ┆   ┆ a cambio   ┆          ┆          ┆       │
# │            ┆            ┆            ┆            ┆   ┆ de         ┆          ┆          ┆       │
# │            ┆            ┆            ┆            ┆   ┆ suspens…   ┆          ┆          ┆       │
# │ TK881      ┆ 49209      ┆ 49.209     ┆ conjunto_m ┆ … ┆ Se procede ┆ 2024     ┆ 39       ┆ M     │
# │            ┆            ┆            ┆ asa_suspen ┆   ┆ cambio de  ┆          ┆          ┆       │
# │            ┆            ┆            ┆ sion       ┆   ┆ suspensió… ┆          ┆          ┆       │
# │ TK878      ┆ 60248      ┆ 60.248     ┆ motor_trac ┆ … ┆ Se procede ┆ 2024     ┆ 39       ┆ M     │
# │            ┆            ┆            ┆ cion       ┆   ┆ a cambio   ┆          ┆          ┆       │
# │            ┆            ┆            ┆            ┆   ┆ de MT1     ┆          ┆          ┆       │
# │            ┆            ┆            ┆            ┆   ┆ por…       ┆          ┆          ┆       │
# └────────────┴────────────┴────────────┴────────────┴───┴────────────┴──────────┴──────────┴───────┘

# %%
df.filter(
    (pl.col("equipment_name") == "864")
    & (pl.col("component_name") == "conjunto_masa_suspension")
).sort("changeout_date", descending=True)
# Out:
# shape: (2, 16)
# ┌────────────┬────────────┬────────────┬────────────┬───┬────────────┬──────────┬──────────┬───────┐
# │ equipment_ ┆ equipment_ ┆ equipment_ ┆ component_ ┆ … ┆ failure_de ┆ iso_year ┆ iso_week ┆ shift │
# │ name       ┆ hours      ┆ hours_icc  ┆ name       ┆   ┆ scription  ┆ ---      ┆ ---      ┆ ---   │
# │ ---        ┆ ---        ┆ ---        ┆ ---        ┆   ┆ ---        ┆ i32      ┆ i8       ┆ str   │
# │ str        ┆ i64        ┆ f64        ┆ str        ┆   ┆ str        ┆          ┆          ┆       │
# ╞════════════╪════════════╪════════════╪════════════╪═══╪════════════╪══════════╪══════════╪═══════╡
# │ TK857      ┆ 74693      ┆ null       ┆ blower_par ┆ … ┆ Se procede ┆ 2025     ┆ 14       ┆ N     │
# │            ┆            ┆            ┆ rilla      ┆   ┆ a cambio   ┆          ┆          ┆       │
# │            ┆            ┆            ┆            ┆   ┆ de blower  ┆          ┆          ┆       │
# │            ┆            ┆            ┆            ┆   ┆ …          ┆          ┆          ┆       │
# │ TK857      ┆ 72485      ┆ 72.485     ┆ blower_par ┆ … ┆ Se procede ┆ 2024     ┆ 47       ┆ M     │
# │            ┆            ┆            ┆ rilla      ┆   ┆ a cambio   ┆          ┆          ┆       │
# │            ┆            ┆            ┆            ┆   ┆ de blower  ┆          ┆          ┆       │
# │            ┆            ┆            ┆            ┆   ┆ …          ┆          ┆          ┆       │
# └────────────┴────────────┴────────────┴────────────┴───┴────────────┴──────────┴──────────┴───────┘

# %%
icc_df = (
    Readr.Reliability.read_icc(context)
    .with_columns(
        has_report=pl.col("report_date").is_not_null(),
        changeout_week=pl.col("changeout_date").dt.strftime("%Y-W%V"),
    )
    .sort("changeout_date", descending=True)
)
cc_df = Readr.Planning.read_cc().sort("changeout_date", descending=True)
weekly_summary_df = generate_weekly_summary(icc_df)
# Out:
# 2025-04-08 17:00:31 -0400 - dagster - INFO - system - Read 123 records from abfs://bhp-analytics-data/RELIABILITY/ICC/icc.parquet.

# %%
df = cc_df.clone().to_pandas()
df = df.loc[df["subcomponent_name"] == "transmision"]
# 1. Ensure 'changeout_date' is in datetime format
df["changeout_date"] = pd.to_datetime(df["changeout_date"])

# 2. Extract the year from the changeout date
df["year"] = df["changeout_date"].dt.year
df.to_csv("components.csv")

# %%
# .to_csv("components.csv")

# %%
# 3. Calculate the total number of changeouts per year
yearly_totals = df.groupby("year").size()

# 4. Filter for changeouts where component_usage is less than 0.8
filtered_df = df[
    df["component_usage"] < 0.8
].copy()  # Use .copy() to avoid SettingWithCopyWarning

# 5. Calculate the number of filtered changeouts per year
yearly_filtered_counts = filtered_df.groupby("year").size()

# 6. Combine the counts into a single DataFrame for easier calculation
summary_df = pd.DataFrame(
    {"total_changeouts": yearly_totals, "filtered_changeouts": yearly_filtered_counts}
)

# Fill NaN with 0 (in case a year has totals but no filtered counts)
summary_df["filtered_changeouts"] = summary_df["filtered_changeouts"].fillna(0)

# 7. Calculate the proportion (handle potential division by zero if a year had 0 changeouts)
summary_df["proportion"] = summary_df.apply(
    lambda row: (
        row["filtered_changeouts"] / row["total_changeouts"]
        if row["total_changeouts"] > 0
        else 0
    ),
    axis=1,
)

# --- Plotting ---

# Create the figure and axes
fig, ax = plt.subplots(figsize=(10, 6))

# Create the bar plot
summary_df["proportion"].plot(kind="bar", ax=ax, color="skyblue")

# Format the y-axis as percentage
ax.yaxis.set_major_formatter(mtick.PercentFormatter(xmax=1.0))

# Set labels and title
ax.set_xlabel("Year")
ax.set_ylabel("Proportion of Changeouts (Usage < 0.8)")
ax.set_title("Proportion of Low Usage (<0.8) Changeouts per Year")
ax.tick_params(axis="x", rotation=45)  # Rotate x-axis labels if needed

# Add grid lines for better readability
ax.grid(axis="y", linestyle="--", alpha=0.7)

# Ensure layout is tight
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 6
#       2 yearly_totals = df.groupby("year").size()
#       4 # 4. Filter for changeouts where component_usage is less than 0.8
#       5 filtered_df = df[
# ----> 6     df["component_usage"] < 0.8
#       7 ].copy()  # Use .copy() to avoid SettingWithCopyWarning
#       9 # 5. Calculate the number of filtered changeouts per year
#      10 yearly_filtered_counts = filtered_df.groupby("year").size()
#
# File ~\DataspellProjects\workspace\venv\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~\DataspellProjects\workspace\venv\Lib\site-packages\pandas\core\arraylike.py:48, in OpsMixin.__lt__(self, other)
#      46 @unpack_zerodim_and_defer("__lt__")
#      47 def __lt__(self, other):
# ---> 48     return self._cmp_method(other, operator.lt)
#
# File ~\DataspellProjects\workspace\venv\Lib\site-packages\pandas\core\series.py:6119, in Series._cmp_method(self, other, op)
#    6116 lvalues = self._values
#    6117 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# -> 6119 res_values = ops.comparison_op(lvalues, rvalues, op)
#    6121 return self._construct_result(res_values, name=res_name)
#
# File ~\DataspellProjects\workspace\venv\Lib\site-packages\pandas\core\ops\array_ops.py:344, in comparison_op(left, right, op)
#     341     return invalid_comparison(lvalues, rvalues, op)
#     343 elif lvalues.dtype == object or isinstance(rvalues, str):
# --> 344     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     346 else:
#     347     res_values = _na_arithmetic_op(lvalues, rvalues, op, is_cmp=True)
#
# File ~\DataspellProjects\workspace\venv\Lib\site-packages\pandas\core\ops\array_ops.py:129, in comp_method_OBJECT_ARRAY(op, x, y)
#     127     result = libops.vec_compare(x.ravel(), y.ravel(), op)
#     128 else:
# --> 129     result = libops.scalar_compare(x.ravel(), y, op)
#     130 return result.reshape(x.shape)
#
# File ops.pyx:107, in pandas._libs.ops.scalar_compare()
#
# TypeError: '<' not supported between instances of 'str' and 'float'

# %%
icc_df.to_pandas().head()
# Out:
#   equipment_name  equipment_hours  equipment_hours_icc      component_name  \
# 0           None              NaN               53.281                None
# 1          TK876              NaN                  NaN    cilindro_levante
# 2          TK857          74693.0                  NaN     modulo_potencia
# 3          TK862          65500.0                  NaN  cilindro_direccion
# 4          TK859          66539.0                  NaN  cilindro_direccion
#
#   component_code position_name  position_code report_date changeout_date  \
# 0           None          None            NaN  2025-01-07            NaT
# 1             CL       derecho            2.0         NaT     2025-04-07
# 2             MP         unico            0.0         NaT     2025-04-07
# 3             CD     izquierdo            1.0         NaT     2025-04-06
# 4             CD       derecho            2.0         NaT     2025-04-04
#
#    customer_work_order                  filename file_type  \
# 0                  NaN  ICC TK876 CD2 2025-01-05       pdf
# 1                 -1.0                      None      None
# 2                 -1.0                      None      None
# 3                 -1.0                      None      None
# 4                 -1.0                      None      None
#
#                                  failure_description  iso_year  iso_week  \
# 0                                               None       NaN       NaN
# 1  Se procede a cambio de cilindro de levante der...    2025.0      15.0
# 2  Se procede a cambio de modulo potencia, ya que...    2025.0      15.0
# 3  Se procede a cambio de cilindro de dirección i...    2025.0      14.0
# 4  Se procede a cambio de cilindro de dirección d...    2025.0      14.0
#
#   shift  has_report changeout_week
# 0  None        True           None
# 1     N       False       2025-W15
# 2     N       False       2025-W15
# 3     N       False       2025-W14
# 4     N       False       2025-W14

# %%
icc_df.to_pandas().head()

# %%
get_shift_dates().filter(pl.col("date").dt.year() >= 2025)

# %%
icc_df.to_pandas()  # .filter(pl.col("equipment_name") == "TK291")

# %%
icc_df.filter(pl.col("equipment_name") == "TK881")

# %%
cc_df.filter(pl.col("equipment_name") == "TK881").filter(
    pl.col("component_name") == "conjunto_masa_suspension"
).sort("changeout_date", descending=True)

# %%
icc_df

# %%
weekly_summary_df

# %%
from kdags.resources.ggplot.core import GGPrism
from kdags.resources.ggplot.basic_plots import bar_plot


def plot_icc_report_alternative(weekly_summary):
    """
    Alternative implementation using the bar_plot function from basic_plots.
    """
    # Create theme instance
    theme = GGPrism()

    # Make sure we're working with a Polars DataFrame
    if not isinstance(weekly_summary, pl.DataFrame):
        weekly_summary = pl.from_pandas(weekly_summary)

    # Create a stacked bar plot
    fig, ax = bar_plot(
        theme=theme,
        df=weekly_summary,
        x="changeout_week",
        y=["available", "missing"],
        figsize=(12, 7),
        stacked=True,
        width=0.85,
    )

    # Get data as numpy arrays for custom annotations
    total = weekly_summary.select("total").to_numpy().flatten()
    missing_percentage = (
        weekly_summary.select("missing_percentage").to_numpy().flatten()
    )

    # Add percentage labels
    for i in range(len(weekly_summary)):
        vertical_offset = 0.3 if total[i] < 5 else 0.4
        percentage_text = (
            f"{int(missing_percentage[i])}%" if missing_percentage[i] > 0 else "0%"
        )

        ax.text(
            i,
            total[i] + vertical_offset,
            percentage_text,
            ha="center",
            va="bottom",
            fontsize=13,
            fontweight="bold",
            color=theme.FIXED_COLORS["axis_color"],
        )

    # Set x-tick rotation
    plt.setp(ax.get_xticklabels(), rotation=90)

    # Ensure y-axis has enough room for labels
    y_max = max(total) + 1.5
    ax.set_ylim(0, y_max)

    # Finalize plot
    theme.finalize_plot(
        fig,
        ax,
        title="Weekly ICC Reports Status",
        xlabel="Week",
        ylabel="Number of Reports",
        legend_title="Report Status",
    )

    return fig, ax


plot_icc_report_alternative(weekly_summary_df)

# %%
icc_df

# %%
icc_df.filter(
    pl.col("filename").str.contains("TK285")
    # & (pl.col("component_name") == "suspension_trasera")
)

# %%
cc_df.filter(
    (pl.col("equipment_name") == "TK285")
    & (pl.col("component_name") == "suspension_trasera")
)  # ICC TK285 ST2 2024-11-12

# %%
from kdags.resources.ggplot import core as ggprism


def plot_icc_report(weekly_summary):
    """
    Create the ICC report visualization with winter bright theme.

    Parameters:
        weekly_summary (pd.DataFrame): Weekly summary DataFrame

    Returns:
        tuple: (fig, ax) - Matplotlib figure and axis objects
    """
    # Create figure with theme
    fig, ax = ggprism.create_figure(figsize=(12, 7))

    # Get data as numpy arrays
    x = np.arange(len(weekly_summary))
    available = weekly_summary["available"].values
    missing = weekly_summary["missing"].values
    total = weekly_summary["total"].values
    missing_percentage = weekly_summary["missing_percentage"].values

    # Plot stacked bars
    ax.bar(
        x,
        available,
        width=0.85,
        color=ggprism.COLORS[0],
        label="Available",
        edgecolor="white",
        linewidth=0.8,
    )
    ax.bar(
        x,
        missing,
        width=0.85,
        bottom=available,
        color=ggprism.COLORS[4],
        label="Missing",
        edgecolor="white",
        linewidth=0.8,
    )

    # Add percentage labels
    for i, row in enumerate(weekly_summary.itertuples()):
        vertical_offset = 0.3
        if row.total >= 5:
            vertical_offset = 0.4

        percentage_text = f"{int(row.missing_percentage)}%" if row.missing > 0 else "0%"
        ax.text(
            i,
            row.total + vertical_offset,
            percentage_text,
            ha="center",
            va="bottom",
            fontsize=13,
            fontweight="bold",
            color=ggprism.AXIS_COLOR,
        )

    # Set x-ticks
    ax.set_xticks(x)
    ax.set_xticklabels(weekly_summary["changeout_week"], rotation=90)

    # Set y-axis limit
    y_max = max(total) + 1.5
    ax.set_ylim(0, y_max)

    # Set labels and title
    ax.set_title(
        "Weekly ICC Reports Status",
        color=ggprism.AXIS_COLOR,
        fontsize=14,
        fontweight="bold",
    )
    ax.set_xlabel("Week", color=ggprism.AXIS_COLOR, fontsize=12, fontweight="bold")
    ax.set_ylabel(
        "Number of Reports", color=ggprism.AXIS_COLOR, fontsize=12, fontweight="bold"
    )

    # Style legend
    ggprism.style_legend(ax, title="Report Status", loc="upper right")

    # Apply tight layout
    plt.tight_layout()

    return fig, ax


plot_icc_report(weekly_summary_df.to_pandas())

# %%
weekly_summary_df = generate_weekly_summary(icc_df)
weekly_summary_df

# %%
icc_df.filter(pl.col("changeout_date").is_null())

# %% [markdown]
# ## Cantidad de reportes faltantes por semana

# %%
df = clean_icc_data(icc_df)
weekly_summary = generate_weekly_summary(df)
fig = plot_icc_report(weekly_summary)

# %%
df.sort_values("changeout_date", ascending=False)

# %% [markdown]
# La semana es de lunes a domingo.

# %% [markdown]
# ## Cambios de componente faltantes

# %%
missing_icc_df = (
    icc_df.loc[icc_df["has_report"] == False]
    .drop(
        columns=[
            "equipment_hours_icc",
            "position_code",
            "report_date",
            "filename",
            "__index_level_0__",
            "has_report",
        ]
    )
    .sort_values("changeout_date")
)


def find_matching_cc_records(missing_icc_df, cc_df):
    # Convert DataFrames to Polars if they aren't already
    if not isinstance(missing_icc_df, pl.DataFrame):
        missing_icc_df = pl.from_pandas(missing_icc_df)
    if not isinstance(cc_df, pl.DataFrame):
        cc_df = pl.from_pandas(
            cc_df[
                [
                    "equipment_name",
                    "component_name",
                    "subcomponent_name",
                    "position_name",
                    "changeout_date",
                    "component_hours",
                    "removed_component_serial",
                    "installed_component_serial",
                    "equipment_hours",
                    "customer_work_order",
                    "failure_description",
                ]
            ].assign(
                equipment_hours=lambda x: pd.to_numeric(
                    x["equipment_hours"], errors="coerce"
                )
            )
        )

    # Ensure changeout_date is properly formatted

    # Prepare results list
    results = []

    # Process each missing ICC record
    for missing_row in missing_icc_df.iter_rows(named=True):
        # Find matching records in cc_df
        matches = cc_df.filter(
            (pl.col("equipment_name") == missing_row["equipment_name"])
            & (pl.col("component_name") == missing_row["component_name"])
            & (pl.col("position_name") == missing_row["position_name"])
            & (pl.col("changeout_date") == missing_row["changeout_date"])
        )

        if matches.height == 0:
            # No match found
            result = {
                "equipment_name": missing_row["equipment_name"],
                "component_name": missing_row["component_name"],
                "position_name": missing_row["position_name"],
                "changeout_date": missing_row["changeout_date"].strftime("%Y-%m-%d"),
                "matches_found": 0,
                "component_hours": "Missing",
                "removed_component_serial": "Missing",
                "installed_component_serial": "Missing",
                "subcomponent_name": "Missing",
            }
        else:
            # Create a result with match information
            match_info = matches.select(
                [
                    "component_hours",
                    "removed_component_serial",
                    "installed_component_serial",
                    "subcomponent_name",
                    "customer_work_order",
                    "equipment_hours",
                    "failure_description",
                ]
            ).to_dicts()[
                0
            ]  # Take the first match if multiple

            result = {
                "equipment_name": missing_row["equipment_name"],
                "component_name": missing_row["component_name"],
                "position_name": missing_row["position_name"],
                "changeout_date": missing_row["changeout_date"].strftime("%Y-%m-%d"),
                "matches_found": matches.height,
                **match_info,
            }

        results.append(result)

    # Create DataFrame from results
    result_df = pl.DataFrame(results)

    # Format component_hours as integers if they're numeric
    result_df = result_df.with_columns(
        component_hours=pl.col("component_hours").cast(pl.Float64, strict=False)
    )

    return result_df


result_df = find_matching_cc_records(missing_icc_df, cc_df).drop(["matches_found"])
result_df = result_df.join(
    pl.from_pandas(
        MasterData.equipments()[
            ["equipment_name", "equipment_serial", "equipment_model"]
        ]
    ),
    on="equipment_name",
    how="left",
)
show(result_df)

# %% [markdown]
# ## Reportes sin ser asignados

# %%
icc_files = [
    f
    for f in (
        Path(os.environ["ONEDRIVE_LOCAL_PATH"]) / "INFORMES_CAMBIO_DE_COMPONENTE"
    ).rglob("*")
    if ((f.is_file()) & (f.suffix == ".pdf") & (f.stem.lower().startswith("icc")))
]
icc_files = pl.DataFrame({"filepath": icc_files}).with_columns(
    filename=pl.col("filepath").map_elements(lambda x: x.stem)
)
unamended_icc = icc_files.join(icc_df, how="left", on="filename")
unamended_icc = unamended_icc.filter(pl.col("report_date").is_null())
if unamended_icc.shape[0] == 0:
    print("No unamended ICC reports found")
unamended_icc

# %%
# icc_files
icc_files
